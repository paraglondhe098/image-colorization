# %%
import numpy as np
import torch
from PIL import Image

# %%
from utils.app.colorizer import ImageColorizer

# %%
colorizer = ImageColorizer("results/experiment_2/final.pt", device = torch.device("cuda"))

# %%
real_img, fake_img = colorizer.colorize(Image.open("data/images/000000000001.jpg"))

# %%
real_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480>

# %%
fake_img
# Out:
# <PIL.Image.Image image mode=RGB size=640x480>
